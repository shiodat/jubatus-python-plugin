# %%
# %matplotlib inline
import math
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from jubatus import Regression
from jubatus.common import Datum
# Out:
# /home/daats/.pyenv/versions/3.6.1/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def train_and_estimate(name):
    regression = Regression('127.0.0.1', 9199, "")
    regression.clear()

    # 学習用データサイズを設定
    n_train = int(len(data)*0.7)

    # 可視化用
    answer = []
    prediction = []
    index = df.index[1:]

    for i in range(len(data)-1):
        # 1期前のデータを入力にして、現在の値を予測する
        x = Datum({"data": data[i]})
        y_true = data[i+1] 

        # [0, n_train]までは学習期間、[n_train:]で予測を実施
        if i > n_train:
            y_pred = regression.estimate([x])[0]  # 予測
        else:
            y_pred = y_true  # 学習期間なので何もしない

        # 現在の値を取得できたので、学習を行う
        regression.train([[y_true, x]])

        # 可視化用に結果を保存
        answer.append(y_true)
        prediction.append(y_pred)

    # jubadump用にモデルを保存    
    regression.save(name)

    # RMSEを計算
    from sklearn.metrics import mean_squared_error
    print(np.sqrt(mean_squared_error(answer[n_train:], prediction[n_train:])))

    # 可視化
    df_result = pd.DataFrame({"answer": answer, "predict": prediction}, index=index)
    df_result.plot(figsize=(18,12))

# %%
def train_and_estimate2(name):
    regression = Regression('127.0.0.1', 9199, "")
    regression.clear()

    # 学習用データサイズを設定
    n_train = int(len(data)*0.7)

    # 可視化用
    answer = []
    prediction = []
    index = df.index[1:]

    for i in range(len(data)-1):
        # 1期前のデータを入力にして、現在の値を予測する
        x = Datum({"data": data[i]})
        y_true = data[i+1] 

        # [0, n_train]までは学習期間、[n_train:]で予測を実施
        if i > n_train:
            y_pred = regression.estimate([Datum({"data": prediction[-1]})])[0]  # 予測
            prediction.append(y_pred)
        else:
            regression.train([[y_true, [Datum({"data": data[i]})]]]) # 学習する
            y_pred = y_true  # 学習期間なので何もしない
            prediction.append(y_pred)

        # 現在の値を取得できたので、学習を行う

        # 可視化用に結果を保存
        answer.append(y_true)

    # jubadump用にモデルを保存    
    regression.save(name)

    # RMSEを計算
    from sklearn.metrics import mean_squared_error
    print(np.sqrt(mean_squared_error(answer[n_train:], prediction[n_train:])))

    # 可視化
    df_result = pd.DataFrame({"answer": answer, "predict": prediction}, index=index)
    df_result.plot(figsize=(18,12))

# %% [markdown]
# # sunsplots dataset

# %%
# データセットの取得
df = sm.datasets.get_rdataset('sunspots').data

# 日付変換 + 整形
def convert_date(date):
    month, year = math.modf(float(date))
    year = round(year)
    month = round(month / (1.0 / 12) + 1)
    return datetime.datetime(year, month, 1)

df.time = df.time.apply(convert_date)
df.index = pd.to_datetime(df.time, format='%Y')
df.sunspots = df.sunspots.astype(float)
df = df.drop('time', axis=1)

# pandas形式をlistに変換する
data = df.sunspots.as_matrix().tolist()

# 可視化
df.plot()

# %%
train_and_estimate2("sunsplots")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-f564ec3cab13> in <module>()
# ----> 1 train_and_estimate2("sunsplots")
#
# <ipython-input-1-ea68ee4121b2> in train_and_estimate2(name)
#      21             prediction.append(y_pred)
#      22         else:
# ---> 23             regression.train([[y_true, [Datum({"data": prediction[-1]})]]]) # 学習する
#      24             y_pred = y_true  # 学習期間なので何もしない
#      25             prediction.append(y_pred)
#
# IndexError: list index out of range

# %% [markdown]
# # Nile Dataset

# %%
# データセットの取得
df = sm.datasets.get_rdataset('Nile').data
df.time = df.time.apply(convert_date)
df.index = pd.to_datetime(df.time, format='%Y')
df.Nile = df.Nile.astype(float)
df = df.drop('time', axis=1)

# pandas形式をlistに変換する
data = df.Nile.as_matrix().tolist()

# 可視化
df.plot()

# %%
train_and_estimate('nile')
# Out:
# 140.264160056

# %% [markdown]
# # UKDriverDeaths

# %%
# データセットの取得
df = sm.datasets.get_rdataset('UKDriverDeaths').data

# 日付変換 + 整形
def convert_date(date):
    month, year = math.modf(float(date))
    year = round(year)
    month = round(month / (1.0 / 12) + 1)
    return datetime.datetime(year, month, 1)

df.time = df.time.apply(convert_date)
df.index = pd.to_datetime(df.time, format='%Y')
df.UKDriverDeaths = df.UKDriverDeaths.astype(float)
df = df.drop('time', axis=1)

# pandas形式をlistに変換する
data = df.UKDriverDeaths.as_matrix().tolist()

# 可視化
df.plot()

# %%
train_and_estimate("ukdeath")
# Out:
# 178.355672985
